# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("List of Countries by Sugarcane Production.csv")
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %%
df.rename(columns = {"Production (Tons)":"Production(Tons)"},inplace = True)
df.rename(columns = {"Production per Person (Kg)":"Production_per_Person(Kg)"},inplace = True)
df.rename(columns = {"Yield (Kg / Hectare)":"Yield(Kg/Hectare)"},inplace = True)
df.rename(columns = {"Acreage (Hectare)":"Acreage(Hectare)"},inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America      768.678.382
# 1           1     India           Asia      348.448.000
# 2           2     China           Asia      123.059.739
# 3           3  Thailand           Asia       87.468.496
# 4           4  Pakistan           Asia       65.450.704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                 3.668,531       10.226.205          75.167,5
# 1                    260721        4.950.000          70.393,5
# 2                     88287        1.675.215          73.459,1
# 3                 1.264,303        1.336.575          65.442,2
# 4                    324219        1.130.820            57.879

# %%
df["Production_per_Person(Kg)"] =df["Production_per_Person(Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage(Hectare)"] =df["Acreage(Hectare)"].str.replace(".","")
df["Yield(Kg/Hectare)"] =df["Yield(Kg/Hectare)"].str.replace(".","").str.replace(",",".")
df["Production(Tons)"] =df["Production(Tons)"].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df["Acreage(Hectare)"].isna()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             0
# Yield(Kg/Hectare)            0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df= df.drop("Unnamed: 0",axis =1)

# %%
df
# Out:
#        Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0       Brazil  South America        768678382                  3668.531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                  1264.303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 100  Singapore           Asia               50                         9
# 101      Samoa        Oceania               12                         6
# 102      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg/Hectare)
# 0           10226205           75167.5
# ...

# %%
df.dropna().reset_index().drop("index",axis = 1)
# Out:
#        Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0       Brazil  South America        768678382                  3668.531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                  1264.303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 99   Singapore           Asia               50                         9
# 100      Samoa        Oceania               12                         6
# 101      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg/Hectare)
# 0           10226205           75167.5
# ...

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df["Production(Tons)"] = df["Production(Tons)"].astype("float")
df["Production_per_Person(Kg)"] = df["Production_per_Person(Kg)"].astype("float")
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype("float")
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype("float")

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %%
plt.figure(figsize = (12,10))
plt.subplot(2,2,1)
plt.title("Production(Tons)	")
sns.distplot(df["Production(Tons)"])
plt.subplot(2,2,2)
plt.title("Production_per_Person(Kg)")
sns.distplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
plt.title("Acreage(Hectare)")
sns.distplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
plt.title("Yield(Kg/Hectare)")
sns.distplot(df["Yield(Kg/Hectare)"])
# Out:
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\1233231481.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\1233231481.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize = (12,10))
plt.subplot(2,2,1)
plt.title("Production(Tons)	")
sns.boxplot(df["Production(Tons)"])
plt.subplot(2,2,2)
plt.title("Production_per_Person(Kg)")
sns.boxplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
plt.title("Acreage(Hectare)")
sns.boxplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
plt.title("Yield(Kg/Hectare)")
sns.boxplot(df["Yield(Kg/Hectare)"])
# Out:
# <Axes: title={'center': 'Yield(Kg/Hectare)'}, ylabel='Yield(Kg/Hectare)'>
# C:\Users\SACHI\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SACHI\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.violinplot(df["Production_per_Person(Kg)"])
# Out:
# <Axes: ylabel='Production_per_Person(Kg)'>

# %%
sns.violinplot(df["Yield(Kg/Hectare)"])
# Out:
# <Axes: ylabel='Yield(Kg/Hectare)'>

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df_new =df[["Production(Tons)","Country"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new.head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df_new["Production(Tons)_percent"] =   df_new["Production(Tons)"]*100/df_new["Production(Tons)"].sum()

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production(Tons)_percent"].plot(kind = "pie",autopct= "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df[["Country","Production(Tons)"]].set_index("Country").sort_values("Production(Tons)",ascending =False).head(15).plot(kind= "bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(x= "Country",y= "Production(Tons)",data = df.head(15))
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\1110842433.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
df_acr= df[["Acreage(Hectare)","Country"]].set_index("Country").head(15).sort_values("Country",ascending = True).plot(kind = "bar")

# %%
df_acr
# Out:
# <Axes: xlabel='Country'>

# %%
df_acr1 = df.sort_values("Acreage(Hectare)",ascending =  False).head(15)
ax= sns.barplot(x= "Country",y = "Acreage(Hectare)",data = df_acr1)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\1890726624.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
df_acr1 = df.sort_values("Yield(Kg/Hectare)",ascending =  False).head(15)
ax= sns.barplot(x= "Country",y = "Yield(Kg/Hectare)",data = df_acr1)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\2761189286.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
df_acr1 = df.sort_values("Production_per_Person(Kg)",ascending =  False).head(15)
ax= sns.barplot(x= "Country",y = "Production_per_Person(Kg)",data = df_acr1)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\SACHI\AppData\Local\Temp\ipykernel_11704\2226220184.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
df.corr
# Out:
# <bound method DataFrame.corr of        Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0       Brazil  South America       768678382.0                   3668.531
# 1        India           Asia       348448000.0                 260721.000
# 2        China           Asia       123059739.0                  88287.000
# 3     Thailand           Asia        87468496.0                   1264.303
# 4     Pakistan           Asia        65450704.0                 324219.000
# ..         ...            ...               ...                        ...
# 97       Spain         Europe             394.0                      8.000
# 98     Lebanon           Asia              97.0                     16.000
# 100  Singapore           Asia              50.0                      9.000
# 101      Samoa        Oceania              12.0                      6.000
# 102      Syria           Asia               1.0                      0.000
#
# ...

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(df_numeric.corr(),annot = True, cmap= "Greens")
plt.show()

# %%
sns.scatterplot(x= "Acreage(Hectare)", y= "Production(Tons)",hue = "Continent",data= df)
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
sns.scatterplot(x= "Yield(Kg/Hectare)", y= "Production(Tons)",hue = "Continent",data= df)
plt.show()
